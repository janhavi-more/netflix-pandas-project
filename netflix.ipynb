# %%
import pandas as pd

nf = pd.read_csv(r"C:\Users\janha\Downloads\PandasLearn\CSV files\netflix_titles.csv", encoding="utf-8")
#print(nf)

nf.sort_values('type')
nf.sort_index()
nf.drop(columns = ['director'])

nfnew = nf.query('title.str.startswith("Ga")', engine='python')
nfbest = nf.loc[nf['release_year'] >= 2020]

nf.at[4, 'type'] #TV show
nf.iat[1, 2] #Blood & Water

# nf.sample(n=2) #any 2
# nf.sample(frac=0.5) #half the Dataframe

# nf.assign(Area = lambda df: df.Length * df.Height) #adding a new columnn
nf.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000
